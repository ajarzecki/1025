# %% [markdown]
# # Installation

# %%
# !pip install tensorflow gradio

# %% [markdown]
# # ResNet50

# %%
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

model = ResNet50(weights='imagenet')

# %% [markdown]
# ## Interactive tests

# %%
import gradio as gr

def recognize(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)

    prediction = model.predict(img)
    return decode_predictions(prediction, top=3)[0][0][1]

gr.Interface(
    fn=recognize,
    inputs=[gr.Image(type="filepath")],
    outputs=["text"]
).launch()
# Out:
# Running on local URL:  http://127.0.0.1:7881
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7881/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Model architecture

# %%
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_5 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_5[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
# ...

# %%
model.output
# Out:
# <KerasTensor: shape=(None, 1000) dtype=float32 (created by layer 'predictions')>

# %% [markdown]
# # Fine Tuning

# %% [markdown]
# ## Pretrained model

# %% [markdown]
# We'll use the same model, but this time with `include_top=False` to remove the original classifier head.
#
# Notice the model now can be used as a universal Feature detector and the shapes in all layers contain only the number of filters, but are resolution independent.

# %%
model2 = ResNet50(weights='imagenet', include_top=False)
model2.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_8 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  conv1_pad (ZeroPadding2D)   (None, None, None, 3)        0         ['input_8[0][0]']
#
#  conv1_conv (Conv2D)         (None, None, None, 64)       9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, None, None, 64)       256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, None, None, 64)       0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, None, None, 64)       0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, None, None, 64)       0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, None, None, 64)       4160      ['pool1_pool[0][0]']
#  D)
#
# ...

# %% [markdown]
# ## DataSets

# %%
import os

_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
path_to_zip = tf.keras.utils.get_file('cats_and_dogs.zip', origin=_URL, extract=True)
PATH = os.path.join(os.path.dirname(path_to_zip), 'cats_and_dogs_filtered')

train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

# %%
# !echo {train_dir}
# !ls -l {train_dir}
# Out:
# /Users/bartoszpampuch/.keras/datasets/cats_and_dogs_filtered/train
# total 0
# drwxr-xr-x@ 1002 bartoszpampuch  staff  32064 Nov  1 01:51 cats
# drwxr-xr-x@ 1002 bartoszpampuch  staff  32064 Nov  1 01:51 dogs

# %%
BATCH_SIZE = 32
IMG_SIZE = (160, 160)

keras.utils.set_random_seed(42)

train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir,
                                                            shuffle=True,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE)


test_dataset = tf.keras.utils.image_dataset_from_directory(validation_dir,
                                                                 shuffle=True,
                                                                 batch_size=BATCH_SIZE,
                                                                 image_size=IMG_SIZE)

class_names = train_dataset.class_names
print("Classes:", class_names)


def one_hot_encode(image, label):
    one_hot_label = tf.one_hot(label, depth=2)
    return image, one_hot_label

train_dataset = train_dataset.map(one_hot_encode)
test_dataset = test_dataset.map(one_hot_encode)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Classes: ['cats', 'dogs']

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))

for images, labels in train_dataset.take(1):
    for i in range(1, 16):
        plt.subplot(4, 4, i)
        plt.imshow(images[i] / 255)
        plt.title(class_names[np.argmax(labels[i])])
        plt.axis('off')

plt.show()

# %% [markdown]
# ## Augmentation

# %% [markdown]
# https://keras.io/api/keras_cv/layers/augmentation/

# %%
# !pip install keras-cv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.1/803.1 kB 4.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 37.0 MB/s eta 0:00:0031m42.5 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 19.3 MB/s eta 0:00:0031m23.3 MB/s eta 0:00:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.9/230.9 kB 28.9 MB/s eta 0:00:00
# ...
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# ...
#   Using cached protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# ...
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21484 sha256=344861f38b625661a2cd9b9ad4d97534195b60a248f06ed16781366170f0172c
#   Stored in directory: /Users/bartoszpampuch/Library/Caches/pip/wheels/54/4e/28/3ed0e1c8a752867445bab994d2340724928aa3ab059c57c8db
# Successfully built promise
# ...
#   Attempting uninstall: protobuf
# ...

# %%
import keras_cv

augmentation_model = tf.keras.Sequential([
  keras_cv.layers.RandAugment([0, 255], seed=42)
])

plt.figure(figsize=(12, 7))

for images, _ in train_dataset.take(1):
    first_image = images[0]
    plt.subplot(2, 3, 1)
    plt.title("Original")
    plt.axis("off")
    plt.imshow(first_image / 255)

    for i in range(2, 7):
        plt.subplot(2, 3, i)
        [augmented_image] = augmentation_model(np.expand_dims(first_image, 0))
        plt.axis("off")
        plt.imshow(augmented_image / 255)

# %% [markdown]
# ## Fine tuning 1/2 Dense Layer

# %%
model2.trainable = False

# %%
inputs = keras.Input(shape=(160, 160, 3))
x = model2(inputs, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.1)(x)
outputs = keras.layers.Dense(2, activation=tf.keras.activations.sigmoid)(x)

model3 = keras.Model(inputs, outputs)
model3.summary()
# Out:
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_29 (InputLayer)       [(None, 160, 160, 3)]     0
#
#  resnet50 (Functional)       (None, None, None, 2048   23587712
#                              )
#
#  global_average_pooling2d_1  (None, 2048)              0
#  7 (GlobalAveragePooling2D)
#
#  dropout_4 (Dropout)         (None, 2048)              0
#
#  dense_17 (Dense)            (None, 2)                 4098
#
# ...
# Total params: 23591810 (90.00 MB)
# Trainable params: 4098 (16.01 KB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model3, show_shapes=True, show_layer_activations=True, show_trainable=True)

# %%
model3.compile(
    optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=1e-4),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy()]
)

model3.evaluate(validation_dataset)
# Out:
# 32/32 [==============================] - 12s 350ms/step - loss: 0.9295 - binary_accuracy: 0.5545
# [0.9294552206993103, 0.5544999837875366]

# %%
history = model3.fit(
    train_dataset,
    batch_size=BATCH_SIZE,
    epochs=10
)
# Out:
# Epoch 1/10
# 63/63 [==============================] - 24s 372ms/step - loss: 0.1192 - binary_accuracy: 0.9525
# Epoch 2/10
# 63/63 [==============================] - 23s 370ms/step - loss: 0.1104 - binary_accuracy: 0.9597
# Epoch 3/10
# 63/63 [==============================] - 23s 370ms/step - loss: 0.1091 - binary_accuracy: 0.9605
# Epoch 4/10
# 63/63 [==============================] - 23s 371ms/step - loss: 0.1007 - binary_accuracy: 0.9638
# Epoch 5/10
# 63/63 [==============================] - 23s 372ms/step - loss: 0.0963 - binary_accuracy: 0.9670
# Epoch 6/10
# 63/63 [==============================] - 24s 375ms/step - loss: 0.0956 - binary_accuracy: 0.9685
# Epoch 7/10
# 63/63 [==============================] - 24s 373ms/step - loss: 0.0907 - binary_accuracy: 0.9690
# Epoch 8/10
# 63/63 [==============================] - 24s 374ms/step - loss: 0.0871 - binary_accuracy: 0.9695
# Epoch 9/10
# ...

# %%
plt.plot(history.history["loss"], label="Loss")
plt.plot(history.history["binary_accuracy"], label="Accuracy")
plt.legend()

# %%
model3.evaluate(test_dataset)
# Out:
# 32/32 [==============================] - 12s 364ms/step - loss: 0.1018 - binary_accuracy: 0.9560
# [0.1017678901553154, 0.9559999704360962]

# %% [markdown]
# ## Fine tuning 2/2 Entire Model

# %% [markdown]
# Now that the additional layers are trained and converged, we can safely retrain the entire model.
#
# For the demo, we'll limit the training to layers above 100 though

# %%
model2.trainable = True

for layer in model2.layers[:100]:
    layer.trainable = False

# %% [markdown]
# Everytime we change the model (including trainable parameters), we have to recompile the model

# %%
model3.compile(
    optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=1e-4),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy()]
)

# %%
tf.keras.utils.plot_model(model3, show_shapes=True, show_layer_activations=True, show_trainable=True)

# %%
history = model3.fit(
    train_dataset,
    batch_size=BATCH_SIZE,
    epochs=3
)

# %%
model3.evaluate(test_dataset)
# Out:
# 32/32 [==============================] - 12s 362ms/step - loss: 0.1091 - binary_accuracy: 0.9685
# [0.10914845019578934, 0.968500018119812]

# %% [markdown]
# # Gradio Tests

# %%
import gradio as gr

def recognize(img_path):
    img = image.load_img(img_path, target_size=(160, 160))
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)

    [prediction] = model3(img)
    print(prediction)
    if np.argmax(prediction) == 1:
        return "Dog"
    return "Cat"

gr.Interface(
    fn=recognize,
    inputs=[gr.Image(type="filepath")],
    outputs=["text"]
).launch()
# Out:
# Running on local URL:  http://127.0.0.1:7888
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7888/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# tf.Tensor([9.9999994e-01 4.5458405e-06], shape=(2,), dtype=float32)
# tf.Tensor([3.8282995e-11 1.0000000e+00], shape=(2,), dtype=float32)
# tf.Tensor([6.079838e-10 1.000000e+00], shape=(2,), dtype=float32)
